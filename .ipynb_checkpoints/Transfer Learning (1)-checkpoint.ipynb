# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.6/46.6 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 55.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 5.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics  import YOLO  #  You only look once

# %%
 model = YOLO("yolo11n.pt")

# %%
pred = model.predict("/content/bicycle.jpg")
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /tmp/ipykernel_3308/943789744.py in <cell line: 0>()
# ----> 1 pred = model.predict(0)
#
# /usr/local/lib/python3.13/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     558         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     559             self.predictor.set_prompts(prompts)
# --> 560         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     561
#     562     def track(
#
# /usr/local/lib/python3.13/dist-packages/ultralytics/engine/predictor.py in __call__(self, source, model, stream, *args, **kwargs)
#     242             return self.stream_inference(source, model, *args, **kwargs)
#     243         else:
# ...

# %%
pred
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
# ...

# %%
pred[0].plot()
# Out:
# array([[[241, 255, 252],
#         [242, 255, 250],
#         [244, 250, 245],
#         ...,
#         [233, 236, 227],
#         [205, 205, 199],
#         [178, 175, 170]],
#
#        [[241, 255, 252],
#         [241, 255, 249],
#         [245, 251, 246],
#         ...,
#         [217, 231, 220],
#         [184, 191, 184],
#         [177, 181, 175]],
#
#        [[240, 255, 251],
#         [242, 253, 250],
#         [246, 251, 249],
#         ...,
#         [198, 231, 217],
#         [159, 183, 173],
#         [170, 189, 180]],
#
#        ...,
#
#        [[128, 221, 200],
#         [123, 229, 206],
#         [115, 241, 219],
#         ...,
#         [195, 200, 209],
#         [193, 198, 207],
#         [195, 200, 209]],
#
#        [[133, 226, 205],
#         [135, 241, 218],
#         [124, 250, 228],
#         ...,
#         [163, 168, 177],
#         [171, 176, 185],
#         [181, 186, 195]],
#
#        [[123, 216, 195],
#         [114, 220, 197],
#         [102, 228, 206],
# ...
