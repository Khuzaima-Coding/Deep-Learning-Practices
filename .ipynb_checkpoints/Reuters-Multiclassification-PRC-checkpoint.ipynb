# %% [markdown]
# # Loading the Reuters Dataset

# %%
from tensorflow.keras.datasets import reuters
(train_data,train_labels),(test_data,test_labels)=reuters.load_data(num_words=10000)

# %%
# reuters.get_word_index().get(,"Not Present")

# %%
len(train_data)
# Out:
# 8982

# %%
len(test_data)
# Out:
# 2246

# %%
train_data.shape  #There is 8982 lists of news present there
# Out:
# (8982,)

# %%
len(train_data[10]) ,len(train_data[0])
# Out:
# (31, 87)

# %%
#Lets we decode our data
word_index = reuters.get_word_index()
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
decoded_newswire = " ".join([reverse_word_index.get(i - 3, "?") for i in train_data[0]])

# %%
decoded_newswire
# Out:
# '? ? ? said as a result of its december acquisition of space co it expects earnings per share in 1987 of 1 15 to 1 30 dlrs per share up from 70 cts in 1986 the company said pretax net should rise to nine to 10 mln dlrs from six mln dlrs in 1986 and rental operation revenues to 19 to 22 mln dlrs from 12 5 mln dlrs it said cash flow per share this year should be 2 50 to three dlrs reuter 3'

# %%
# Lets we can encode our training Data
import numpy as np
def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
      for j in sequence:
        results[i, j] = 1.
    return results

# %%
x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

# %%
x_train.shape
# Out:
# (8982, 10000)

# %%
y_train = np.asarray(train_labels).astype("float32")
y_test = np.asarray(test_labels).astype("float32")

# %%
# def to_one_hot(labels, dimension=46):
#     results = np.zeros((len(labels), dimension))
#     for i, label in enumerate(labels):
#         results[i, label] = 1. 
#     return results

# %%
# y_train = to_one_hot(train_labels)   
# y_test = to_one_hot(test_labels)

# %% [raw]
# BETTER WAY

# %%
#This is the another built in way to encode lebels in keras
# from tensorflow.keras.utils import to_categorical
# y_train = to_categorical(train_labels)
# y_test = to_categorical(test_labels)

# %%
y_train
# Out:
# array([ 3.,  4.,  3., ..., 25.,  3., 25.], shape=(8982,), dtype=float32)

# %%
y_test
# Out:
# array([ 3., 10.,  1., ...,  3.,  3., 24.], shape=(2246,), dtype=float32)

# %% [markdown]
# ## Model Defining

# %%
from tensorflow import keras
from keras import layers
model = keras.Sequential([
    layers.Dense(64, activation="relu"),
    layers.Dense(64, activation="relu"),
    layers.Dense(46, activation="softmax")
])

# %%
#Compiling Our Model
model.compile(optimizer="rmsprop",
      loss="sparse_categorical_crossentropy",  #we do there categorical_crossentropy ,because we encode our labels above 
      metrics=["accuracy"])

# %%
# We seperating our training and validation data there
x_val = x_train[:1000]
partial_x_train = x_train[1000:]
y_val = y_train[:1000]
partial_y_train = y_train[1000:]

# %% [markdown]
# ### Training Our Model

# %%
history = model.fit(partial_x_train,
partial_y_train,
epochs=20,
batch_size=512,
validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.4896 - loss: 2.7203 - val_accuracy: 0.5590 - val_loss: 1.8557
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.6428 - loss: 1.5969 - val_accuracy: 0.6680 - val_loss: 1.4562
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.7241 - loss: 1.2606 - val_accuracy: 0.7180 - val_loss: 1.2558
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.7730 - loss: 1.0439 - val_accuracy: 0.7550 - val_loss: 1.1335
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.8106 - loss: 0.8779 - val_accuracy: 0.7820 - val_loss: 1.0713
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.8448 - loss: 0.7372 - val_accuracy: 0.7880 - val_loss: 1.0029
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.8673 - loss: 0.6258 - val_accuracy: 0.8030 - val_loss: 0.9410
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.8872 - loss: 0.5326 - val_accuracy: 0.8090 - val_loss: 0.9092
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9050 - loss: 0.4490 - val_accuracy: 0.8130 - val_loss: 0.8995
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9177 - loss: 0.3882 - val_accuracy: 0.8210 - val_loss: 0.8868
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9298 - loss: 0.3311 - val_accuracy: 0.8060 - val_loss: 0.8949
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.9376 - loss: 0.2832 - val_accuracy: 0.8190 - val_loss: 0.8927
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.9436 - loss: 0.2517 - val_accuracy: 0.8190 - val_loss: 0.8923
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9456 - loss: 0.2263 - val_accuracy: 0.8230 - val_loss: 0.8801
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.9495 - loss: 0.2018 - val_accuracy: 0.8240 - val_loss: 0.8873
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.9514 - loss: 0.1842 - val_accuracy: 0.8110 - val_loss: 0.9518
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.9543 - loss: 0.1677 - val_accuracy: 0.8130 - val_loss: 0.9288
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9554 - loss: 0.1538 - val_accuracy: 0.8130 - val_loss: 0.9209
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9565 - loss: 0.1469 - val_accuracy: 0.8180 - val_loss: 0.9568
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9574 - loss: 0.1376 - val_accuracy: 0.8240 - val_loss: 0.9323

# %%
history_dict=history.history

# %%
import pandas as pd
pd.DataFrame(history_dict)
# Out:
#     accuracy      loss  val_accuracy  val_loss
# 0   0.489602  2.720318         0.559  1.855724
# 1   0.642821  1.596921         0.668  1.456205
# 2   0.724129  1.260595         0.718  1.255828
# 3   0.772989  1.043872         0.755  1.133511
# 4   0.810574  0.877928         0.782  1.071258
# 5   0.844776  0.737241         0.788  1.002913
# 6   0.867326  0.625752         0.803  0.941044
# 7   0.887246  0.532596         0.809  0.909177
# 8   0.905036  0.448972         0.813  0.899514
# 9   0.917690  0.388191         0.821  0.886779
# 10  0.929842  0.331075         0.806  0.894857
# 11  0.937610  0.283233         0.819  0.892727
# 12  0.943623  0.251659         0.819  0.892273
# 13  0.945628  0.226325         0.823  0.880068
# 14  0.949511  0.201754         0.824  0.887255
# 15  0.951391  0.184217         0.811  0.951814
# 16  0.954272  0.167729         0.813  0.928783
# 17  0.955400  0.153820         0.813  0.920936
# 18  0.956527  0.146855         0.818  0.956816
# 19  0.957404  0.137629         0.824  0.932265

# %% [markdown]
# ## Training and Validation Loss

# %%
import matplotlib.pyplot as plt
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.clf()  #It clears the figure
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
#Retraining Our Model From Scratch
from tensorflow import keras
from keras import layers
model=keras.Sequential([
    layers.Dense(64,activation="relu"),
    layers.Dense(64,activation="relu"),
    layers.Dense(46,activation="softmax")
])

# %%
#compiling Our Model
model.compile(optimizer="rmsprop",loss="sparse_categorical_crossentropy",metrics=["accuracy"])

# %%
model.fit(x_train,
  y_train,
  epochs=9,
  batch_size=512)
results = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - accuracy: 0.4709 - loss: 2.7484
# Epoch 2/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.6642 - loss: 1.5432
# Epoch 3/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.7455 - loss: 1.1838
# Epoch 4/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7938 - loss: 0.9715
# Epoch 5/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8277 - loss: 0.8052
# Epoch 6/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8517 - loss: 0.6757
# Epoch 7/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.8798 - loss: 0.5619
# Epoch 8/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.8969 - loss: 0.4736
# Epoch 9/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9119 - loss: 0.4000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7943 - loss: 0.9166

# %%
results
# Out:
# [0.9165618419647217, 0.7943009734153748]

# %%
#Original dictionary
reuters_label_dict = {'copper': 6, 'livestock': 28, 'gold': 25, 'money-fx': 19, 'ipi': 30, 'trade': 11, 'cocoa': 0, 'iron-steel': 31, 'reserves': 12, 'tin': 26, 'zinc': 37, 'jobs': 34, 'ship': 13, 'cotton': 14, 'alum': 23, 'strategic-metal': 27, 'lead': 45, 'housing': 7, 'meal-feed': 22, 'gnp': 21, 'sugar': 10, 'rubber': 32, 'dlr': 40, 'veg-oil': 2, 'interest': 20, 'crude': 16, 'coffee': 9, 'wheat': 5, 'carcass': 15, 'lei': 35, 'gas': 41, 'nat-gas': 17, 'oilseed': 24, 'orange': 38, 'heat': 33, 'wpi': 43, 'silver': 42, 'cpi': 18, 'earn': 3, 'bop': 36, 'money-supply': 8, 'hog': 44, 'acq': 4, 'pet-chem': 39, 'grain': 1, 'retail': 29}

#reverse the dictionary
reuters_label_reversed = {v:k for k, v in reuters_label_dict.items()}

# %%
predictions=model.predict(x_test)
# Out:
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step

# %%
predictions[0].shape
# Out:
# (46,)

# %%
y_pred=[]
for p in predictions:
    y_pred.append(reuters_label_reversed.get(np.argmax(p)))
y_pred
# Out:
# ['earn',
#  'sugar',
#  'grain',
#  'acq',
#  'ship',
#  'earn',
#  'earn',
#  'earn',
#  'earn',
#  'earn',
#  'grain',
#  'acq',
#  'grain',
#  'earn',
#  'grain',
#  'trade',
#  'earn',
#  'earn',
#  'money-fx',
#  'earn',
#  'money-supply',
#  'earn',
#  'earn',
#  'earn',
#  'coffee',
#  'earn',
#  'acq',
#  'copper',
#  'sugar',
#  'earn',
#  'earn',
#  'sugar',
#  'crude',
#  'earn',
#  'money-fx',
#  'acq',
#  'interest',
#  'grain',
#  'acq',
#  'earn',
#  'grain',
#  'gnp',
#  'earn',
#  'reserves',
#  'acq',
#  'acq',
#  'earn',
#  'acq',
#  'earn',
#  'trade',
#  'interest',
#  'earn',
#  'earn',
#  'earn',
#  'earn',
#  'money-fx',
#  'veg-oil',
#  'acq',
#  'interest',
#  'money-fx',
#  'acq',
#  'earn',
#  'acq',
#  'acq',
#  'acq',
#  'earn',
#  'earn',
#  'grain',
#  'earn',
#  'acq',
#  'earn',
#  'acq',
#  'earn',
#  'money-fx',
#  'wpi',
#  'oilseed',
#  'grain',
#  'earn',
#  'interest',
#  'acq',
#  'earn',
#  'earn',
#  'earn',
#  'trade',
#  'money-fx',
#  'interest',
#  'earn',
#  'money-fx',
#  'acq',
#  'earn',
#  'earn',
#  'acq',
#  'earn',
#  'interest',
#  'earn',
#  'trade',
#  'trade',
#  'earn',
#  'acq',
#  'veg-oil',
#  'gas',
#  'earn',
#  'interest',
#  'earn',
#  'earn',
#  'veg-oil',
#  'acq',
#  'ship',
#  'acq',
#  'earn',
#  'money-fx',
#  'earn',
#  'acq',
#  'earn',
#  'crude',
#  'earn',
#  'acq',
#  'acq',
#  'earn',
#  'acq',
#  'earn',
#  'earn',
#  'money-fx',
#  'acq',
#  'cpi',
#  'earn',
#  'money-fx',
#  'earn',
#  'acq',
#  'earn',
#  'money-supply',
#  'earn',
#  'grain',
#  'earn',
#  'trade',
#  'acq',
#  'ship',
#  'grain',
#  'earn',
#  'earn',
#  'earn',
#  'earn',
#  'acq',
#  'acq',
#  'interest',
#  'grain',
#  'acq',
#  'copper',
#  'earn',
#  'earn',
#  'acq',
#  'acq',
#  'earn',
#  'earn',
#  'acq',
#  'grain',
#  'earn',
#  'earn',
#  'trade',
#  'nat-gas',
#  'earn',
#  'earn',
#  'veg-oil',
#  'acq',
#  'earn',
#  'acq',
#  'earn',
#  'sugar',
#  'earn',
#  'earn',
#  'earn',
#  'interest',
#  'earn',
#  'reserves',
#  'earn',
#  'gnp',
#  'acq',
#  'money-fx',
#  'earn',
#  'earn',
#  'earn',
#  'money-supply',
#  'earn',
#  'money-fx',
#  'earn',
#  'gnp',
#  'earn',
#  'earn',
#  'copper',
#  'lei',
#  'money-supply',
#  'earn',
#  'trade',
#  'trade',
#  'money-supply',
#  'gnp',
#  'earn',
#  'acq',
#  'interest',
#  'acq',
#  'crude',
#  'crude',
#  'money-fx',
#  'earn',
#  'earn',
#  'acq',
#  'acq',
#  'money-fx',
#  'veg-oil',
#  'acq',
#  'earn',
#  'acq',
#  'earn',
#  'earn',
#  'earn',
#  'interest',
#  'acq',
#  'gnp',
#  'earn',
#  'earn',
#  'earn',
#  'earn',
#  'earn',
#  'acq',
#  'ship',
#  'earn',
#  'ship',
#  'ship',
#  'acq',
#  'earn',
#  'acq',
#  'money-fx',
#  'earn',
#  'trade',
#  'coffee',
#  'grain',
#  'earn',
#  'earn',
#  'trade',
#  'grain',
#  'money-fx',
#  'grain',
#  'acq',
#  'acq',
#  'trade',
#  'earn',
#  'earn',
#  'acq',
#  'interest',
#  'earn',
#  'acq',
#  'acq',
#  'earn',
#  'earn',
#  'gold',
#  'acq',
#  'iron-steel',
#  'acq',
#  'tin',
#  'trade',
#  'money-fx',
#  'acq',
#  'acq',
#  'acq',
#  'gnp',
#  'earn',
#  'acq',
#  'acq',
#  'earn',
#  'sugar',
#  'acq',
#  'money-fx',
#  'earn',
#  'earn',
#  'interest',
#  'earn',
#  'acq',
#  'money-fx',
#  'crude',
#  'earn',
#  'earn',
#  'acq',
#  'crude',
#  'acq',
#  'earn',
#  'earn',
#  'earn',
#  'earn',
#  'acq',
#  'sugar',
#  'earn',
#  'acq',
#  'grain',
#  'earn',
#  'acq',
#  'crude',
#  'acq',
#  'acq',
#  'acq',
#  'crude',
#  'earn',
#  'trade',
#  'earn',
#  'money-fx',
#  'trade',
#  'earn',
#  'copper',
#  'earn',
#  'crude',
#  'earn',
#  'crude',
#  'gnp',
#  'acq',
#  'earn',
#  'acq',
#  'grain',
#  'crude',
#  'acq',
#  'veg-oil',
#  'earn',
#  'earn',
#  'earn',
#  'gold',
#  'money-supply',
#  'earn',
#  'earn',
#  'trade',
#  'earn',
#  'money-fx',
#  'acq',
#  'money-fx',
#  'earn',
#  'acq',
#  'earn',
#  'earn',
#  'trade',
#  'crude',
#  'money-fx',
#  'tin',
#  'earn',
#  'money-fx',
#  'acq',
#  'earn',
#  'earn',
#  'acq',
#  'earn',
#  'acq',
#  'earn',
#  'crude',
#  'acq',
#  'acq',
#  'earn',
#  'earn',
#  'earn',
#  'money-fx',
#  'cpi',
#  'earn',
#  'coffee',
#  'earn',
#  'acq',
#  'acq',
#  'sugar',
#  'acq',
#  'gnp',
#  'earn',
#  'earn',
#  'ship',
#  'earn',
#  'earn',
#  'trade',
#  'trade',
#  'grain',
#  'acq',
#  'grain',
#  'trade',
#  'earn',
#  'trade',
#  'earn',
#  'earn',
#  'earn',
#  'sugar',
#  'earn',
#  'earn',
#  'crude',
#  'money-fx',
#  'money-fx',
#  'coffee',
#  'earn',
#  'trade',
#  'crude',
#  'earn',
#  'hog',
#  'crude',
#  'earn',
#  'grain',
#  'earn',
#  'earn',
#  'crude',
#  'acq',
#  'money-fx',
#  'acq',
#  'trade',
#  'acq',
#  'earn',
#  'money-fx',
#  'acq',
#  'earn',
#  'earn',
#  'grain',
#  'earn',
#  'earn',
#  'acq',
#  'acq',
#  'earn',
#  'earn',
#  'acq',
#  'earn',
#  'acq',
#  'grain',
#  'acq',
#  'earn',
#  'grain',
#  'grain',
#  'acq',
#  'earn',
#  'earn',
#  'acq',
#  'trade',
#  'earn',
#  'trade',
#  'earn',
#  'earn',
#  'earn',
#  'earn',
#  'earn',
#  'acq',
#  'acq',
#  'grain',
#  'money-fx',
#  'money-fx',
#  'sugar',
#  'earn',
#  'acq',
#  'earn',
#  'acq',
#  'money-supply',
#  'gnp',
#  'grain',
#  'earn',
#  'money-supply',
#  'money-fx',
#  'money-fx',
#  'jobs',
#  'earn',
#  'acq',
#  'earn',
#  'earn',
#  'earn',
#  'iron-steel',
#  'money-fx',
#  'acq',
#  'acq',
#  'interest',
#  'earn',
#  'acq',
#  'acq',
#  'earn',
#  'ship',
#  'acq',
#  'earn',
#  'money-fx',
#  'acq',
#  'acq',
#  'earn',
#  'money-supply',
#  'trade',
#  'acq',
#  'earn',
#  'acq',
#  'earn',
#  'earn',
#  'earn',
#  'crude',
#  'earn',
#  'trade',
#  'earn',
#  'money-fx',
#  'money-fx',
#  'acq',
#  'earn',
#  'earn',
#  'earn',
#  'earn',
#  'earn',
#  'acq',
#  'interest',
#  'copper',
#  'earn',
#  'acq',
#  'earn',
#  'earn',
#  'earn',
#  'acq',
#  'grain',
#  'acq',
#  'acq',
#  'earn',
#  'acq',
#  'acq',
#  'earn',
#  'earn',
#  'grain',
#  'money-fx',
#  'acq',
#  'coffee',
#  'acq',
#  'coffee',
#  'grain',
#  'earn',
#  'trade',
#  'earn',
#  'earn',
#  'acq',
#  'gnp',
#  'acq',
#  'earn',
#  'money-fx',
#  'ship',
#  'acq',
#  'hog',
#  'acq',
#  'ship',
#  'acq',
#  'interest',
#  'acq',
#  'acq',
#  'earn',
#  'trade',
#  'ipi',
#  'tin',
#  'veg-oil',
#  'oilseed',
#  'earn',
#  'coffee',
#  'acq',
#  'gnp',
#  'coffee',
#  'acq',
#  'jobs',
#  'earn',
#  'acq',
#  'earn',
#  'crude',
#  'acq',
#  'sugar',
#  'earn',
#  'earn',
#  'trade',
#  'earn',
#  'earn',
#  'earn',
#  'interest',
#  'earn',
#  'earn',
#  'acq',
#  'trade',
#  'earn',
#  'acq',
#  'earn',
#  'money-supply',
#  'earn',
#  'crude',
#  'crude',
#  'earn',
#  'acq',
#  'acq',
#  'acq',
#  'trade',
#  'earn',
#  'earn',
#  'earn',
#  'acq',
#  'earn',
#  'earn',
#  'crude',
#  'acq',
#  'gold',
#  'trade',
#  'acq',
#  'livestock',
#  'acq',
#  'earn',
#  'acq',
#  'earn',
#  'money-supply',
#  'earn',
#  'earn',
#  'crude',
#  'earn',
#  'bop',
#  'earn',
#  'cpi',
#  'earn',
#  'earn',
#  'acq',
#  'interest',
#  'acq',
#  'earn',
#  'acq',
#  'trade',
#  'money-fx',
#  'interest',
#  'iron-steel',
#  'acq',
#  'earn',
#  'earn',
#  'earn',
#  'crude',
#  'cocoa',
#  'grain',
#  'acq',
#  'earn',
#  'earn',
#  'grain',
#  'acq',
#  'earn',
#  'money-fx',
#  'trade',
#  'earn',
#  'trade',
#  'acq',
#  'earn',
#  'crude',
#  'earn',
#  'earn',
#  'money-fx',
#  'acq',
#  'money-supply',
#  'money-fx',
#  'earn',
#  'earn',
#  'earn',
#  'earn',
#  'earn',
#  'earn',
#  'ship',
#  'cpi',
#  'earn',
#  'money-fx',
#  'grain',
#  'crude',
#  'acq',
#  'earn',
#  'earn',
#  'acq',
#  'earn',
#  'crude',
#  'acq',
#  'acq',
#  'veg-oil',
#  'acq',
#  'money-fx',
#  'earn',
#  'money-fx',
#  'money-supply',
#  'earn',
#  'earn',
#  'acq',
#  'ship',
#  'earn',
#  'acq',
#  'acq',
#  'earn',
#  'acq',
#  'earn',
#  'earn',
#  'interest',
#  'grain',
#  'money-fx',
#  'earn',
#  'acq',
#  'crude',
#  'earn',
#  'crude',
#  'earn',
#  'earn',
#  'earn',
#  'grain',
#  'earn',
#  'money-fx',
#  'interest',
#  'acq',
#  'grain',
#  'earn',
#  'earn',
#  'interest',
#  'ipi',
#  'trade',
#  'grain',
#  'earn',
#  'money-fx',
#  'grain',
#  'ship',
#  'acq',
#  'earn',
#  'gold',
#  'acq',
#  'money-fx',
#  'earn',
#  'gnp',
#  'alum',
#  'earn',
#  'earn',
#  'grain',
#  'money-supply',
#  'earn',
#  'earn',
#  'reserves',
#  'earn',
#  'money-fx',
#  'acq',
#  'interest',
#  'acq',
#  'acq',
#  'acq',
#  'earn',
#  'earn',
#  'alum',
#  'earn',
#  'money-fx',
#  'earn',
#  'ipi',
#  'earn',
#  'crude',
#  'earn',
#  'earn',
#  'trade',
#  'earn',
#  'acq',
#  'earn',
#  'acq',
#  'coffee',
#  'earn',
#  'cocoa',
#  'money-fx',
#  'earn',
#  'acq',
#  'earn',
#  'acq',
#  'earn',
#  'acq',
#  'earn',
#  'earn',
#  'earn',
#  'acq',
#  'crude',
#  'gnp',
#  'acq',
#  'acq',
#  'grain',
#  'money-fx',
#  'alum',
#  'acq',
#  'acq',
#  'earn',
#  'acq',
#  'earn',
#  'earn',
#  'crude',
#  'money-fx',
#  'earn',
#  'acq',
#  'earn',
#  'sugar',
#  'earn',
#  'earn',
#  'earn',
#  'trade',
#  'earn',
#  'trade',
#  'cocoa',
#  'earn',
#  'veg-oil',
#  'earn',
#  'grain',
#  'earn',
#  'ship',
#  'acq',
#  'earn',
#  'earn',
#  'earn',
#  'money-fx',
#  'sugar',
#  'earn',
#  'acq',
#  'acq',
#  'earn',
#  'money-fx',
#  'acq',
#  'interest',
#  'grain',
#  'acq',
#  'acq',
#  'earn',
#  'trade',
#  'acq',
#  'trade',
#  'acq',
#  'acq',
#  'earn',
#  'acq',
#  'earn',
#  'earn',
#  'earn',
#  'trade',
#  'trade',
#  'earn',
#  'earn',
#  'money-fx',
#  'grain',
#  'alum',
#  'trade',
#  'acq',
#  'earn',
#  'earn',
#  'earn',
#  'money-fx',
#  'earn',
#  'earn',
#  'trade',
#  'earn',
#  'earn',
#  'acq',
#  'interest',
#  'earn',
#  'earn',
#  'iron-steel',
#  'sugar',
#  'earn',
#  'earn',
#  'earn',
#  'grain',
#  'trade',
#  'earn',
#  'acq',
#  'gold',
#  'acq',
#  'copper',
#  'trade',
#  'coffee',
#  'earn',
#  'interest',
#  'crude',
#  'trade',
#  'money-fx',
#  'money-supply',
#  'acq',
#  'earn',
#  'acq',
#  'trade',
#  'earn',
#  'earn',
#  'trade',
#  'acq',
#  'oilseed',
#  'crude',
#  'trade',
#  'grain',
#  'crude',
#  'earn',
#  'crude',
#  'money-fx',
#  'grain',
#  'earn',
#  'coffee',
#  'rubber',
#  'crude',
#  'interest',
#  'earn',
#  'earn',
#  'livestock',
#  'earn',
#  'money-supply',
#  'earn',
#  'earn',
#  'grain',
#  'grain',
#  'ship',
#  'acq',
#  'acq',
#  'trade',
#  'grain',
#  'interest',
#  'earn',
#  'earn',
#  'earn',
#  'carcass',
#  'trade',
#  'interest',
#  'grain',
#  'earn',
#  'money-supply',
#  'money-supply',
#  'money-fx',
#  'interest',
#  'earn',
#  'earn',
#  'acq',
#  'earn',
#  'earn',
#  'acq',
#  'heat',
#  'earn',
#  'earn',
#  'earn',
#  'earn',
#  'grain',
#  'gnp',
#  'acq',
#  'earn',
#  'money-fx',
#  'earn',
#  'grain',
#  'earn',
#  'earn',
#  'trade',
#  'earn',
#  'earn',
#  'interest',
#  'earn',
#  'money-fx',
#  'money-supply',
#  'grain',
#  'trade',
#  'interest',
#  'acq',
#  'gold',
#  'grain',
#  'acq',
#  'earn',
#  'oilseed',
#  'acq',
#  'money-fx',
#  'earn',
#  'gnp',
#  'acq',
#  'earn',
#  'acq',
#  'crude',
#  'grain',
#  'money-fx',
#  'grain',
#  'earn',
#  'acq',
#  'earn',
#  'earn',
#  'sugar',
#  'money-supply',
#  'tin',
#  'gold',
#  'earn',
#  'crude',
#  'earn',
#  'earn',
#  'earn',
#  'crude',
#  'acq',
#  'earn',
#  'gold',
#  'earn',
#  'earn',
#  'earn',
#  'alum',
#  'earn',
#  'money-fx',
#  'earn',
#  'earn',
#  'crude',
#  'earn',
#  'acq',
#  'grain',
#  'copper',
#  'money-fx',
#  'trade',
#  'earn',
#  'earn',
#  'gold',
#  'earn',
#  'acq',
#  'earn',
#  'grain',
#  'interest',
#  'crude',
#  'earn',
#  'acq',
#  'earn',
#  'acq',
#  'earn',
#  'earn',
#  'earn',
#  ...]
