# %%
from tensorflow.keras.datasets import mnist

# %%
(train_images,train_labels),(test_images,test_labels)=mnist.load_data()

# %%
train_images.shape,test_images.shape,train_labels.shape,test_labels.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28), (60000,), (10000,))

# %%
train_labels[0]
# Out:
# np.uint8(5)

# %%
train_images[0].shape
# Out:
# (28, 28)

# %%
import matplotlib.pyplot as plt
digit=train_images[0]
plt.imshow(digit,cmap=plt.cm.binary)
plt.show()

# %%
from tensorflow import keras
from tensorflow.keras import layers
model=keras.Sequential([                              #There we can add the layers in list form
    layers.Dense(512,activation="relu"),
    layers.Dense(10,activation="softmax")
])

# %%
#There we add the layers step by step
from tensorflow.keras import models
from tensorflow.keras import layers
network=models.Sequential()
network.add(layers.Dense(512,activation="relu"))
network.add(layers.Dense(10,activation="softmax"))

# %%
model.compile(optimizer="rmsprop",loss="sparse_categorical_crossentropy",metrics=["accuracy"])
#In this optimizer can do the backpropagation,means in reverse direction it can changes the weights.
# SGD
# RMSprop
# Adam
# Adam
# Adadelta
# Adagrad
# Adamax
# Adafactor
# Nadam
# Ftrl
# These are multiple optimizers ,they have different matematical techniques to optimize weights.

#Loss is the difference between the predicted and original value and categorical_crossentropy is its function for loss.
#metrics=["accuracy"] is the performance matrics.by which we can the performance of our data.

# %%
train_images = train_images.reshape(60000,784)   # we do this for converting our values into vector form ,bec our Dense layer required this
train_images=train_images.astype("float32")/255   #we can divide our images values by 255 ,Bec our maximum value is 255 in rgb colors(in pixels).
test_images=test_images.reshape(10000,784)
test_images=test_images.astype("float32")/255     #we do this for coverting the values from 0 till 1

# %%
model.fit(train_images,train_labels,epochs=5,batch_size=128)
#epochs can do the back propagation ,till 5 times.
#batch_size=128 ,It can select the 128 images(vectors),at each time,and can update the whole batch weight at  once,that can speed up our propagations.
# Out:
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9246 - loss: 0.2644
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9680 - loss: 0.1080
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9790 - loss: 0.0707
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9850 - loss: 0.0507
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9888 - loss: 0.0386

# %%
# Epoch 1/5
# 469/469 
#There is shown 469 because our weight can be updated at 469 times
#If we rerun this cell ,so it can increase its accuracy ,from where it leaves behind that accuracy.

# %% [raw]
# We want to encode our labels ,
# First we encode our labels by ourselves ,
# Second we give the encoded data to our model by using sparse_categorical_crossentropy function at loss in model compilation.

# %%
#Predict

# %%
test_digits = test_images[0:10] #it slice from 0 till 9 indexes of our testing images
predictions = model.predict(test_digits)
predictions[0]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# array([1.8947998e-07, 1.9726558e-08, 4.6231648e-06, 1.0774711e-04,
#        3.7419668e-11, 1.3359142e-08, 9.2201368e-12, 9.9988604e-01,
#        1.6885775e-07, 1.1988153e-06], dtype=float32)

# %%
predictions[0].argmax()  #argmax can finds the maximum value of probability and give its index
# Out:
# np.int64(7)

# %%
test_labels[0]
# Out:
# np.uint8(7)

# %%
predictions[9].argmax()
# Out:
# np.int64(9)

# %%
test_labels[9]
# Out:
# np.uint8(9)

# %%
predictions[1].argmax()
# Out:
# np.int64(2)

# %%
test_labels[1]
# Out:
# np.uint8(2)

# %%
#we can also target a single index
inp=test_images[12].reshape(1,784)

# %%
model.predict(inp).argmax()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step
# np.int64(9)

# %%
test_labels[12]
# Out:
# np.uint8(9)

# %%
for p in predictions:
    print(p.argmax())
# Out:
# 7
# 2
# 1
# 0
# 4
# 1
# 4
# 9
# 6
# 9

# %%
test_labels[0:10]
# Out:
# array([7, 2, 1, 0, 4, 1, 4, 9, 5, 9], dtype=uint8)

# %%
#Evaluate

# %%
test_loss,test_acc=model.evaluate(test_images,test_labels)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9797 - loss: 0.0663

# %%
test_loss
# Out:
# 0.06627890467643738

# %%
test_acc
# Out:
# 0.9797000288963318
